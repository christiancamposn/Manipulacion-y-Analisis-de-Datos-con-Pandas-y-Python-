# %% [markdown]
# <a href="https://colab.research.google.com/github/christiancamposn/Manipulacion-y-Analisis-de-Datos-con-Pandas-y-Python-/blob/main/11_Borrar_filas%2C_columnas_y_copiar_informaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas

# %%
import pandas as pd
pd.__version__
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
dir_pandas = '/content/drive/My Drive/Colab Notebooks/db/{}'.format('')
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/'

# %%
df_meteorites = pd.read_csv( dir_pandas +'Meteorite_Landings.csv')

# %%
df_meteorites
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
df_meteorites.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall    year  \
# 0               Aachen    1    Valid           L5      21.0  Fell  1880.0
# 1               Aarhus    2    Valid           H6     720.0  Fell  1951.0
# 2                 Abee    6    Valid          EH4  107000.0  Fell  1952.0
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0
# 4              Achiras  370    Valid           L6     780.0  Fell  1902.0
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell  1919.0
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell  1949.0
# 7                 Agen  392    Valid           H5   30000.0  Fell  1814.0
# 8               Aguada  398    Valid           L6    1620.0  Fell  1930.0
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell  1920.0
#
#      reclat    reclong           GeoLocation
# 0  50.77500    6.08333     (50.775, 6.08333)
# 1  56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
df_meteorites.tail(10)
# Out:
#              name     id nametype              recclass   mass (g)   fall  \
# 45706     Zerkaly  31354    Valid                    H5    16000.0  Found
# 45707    Zhaoping  54609    Valid     Iron, IAB complex  2000000.0  Found
# 45708    Zhigansk  30405    Valid           Iron, IIIAB   900000.0  Found
# 45709  Zhongxiang  30406    Valid                  Iron   100000.0  Found
# 45710  Zillah 001  31355    Valid                    L6     1475.0  Found
# 45711  Zillah 002  31356    Valid               Eucrite      172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46.0  Found
# 45713        Zlin  30410    Valid                    H4        3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6     2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200.0  Found
#
#          year    reclat    reclong             GeoLocation
# 45706  1956.0  52.13333   81.96667    (52.13333, 81.96667)
# ...

# %%
df_meteorites.sample(10)
# Out:
#                                name     id nametype     recclass  mass (g)  \
# 36158          Roberts Massif 04190  44622    Valid           L6    191.50
# 24646            Miller Range 07271  51293    Valid           H6     21.70
# 4788                   Asuka 881902   4611    Valid  Acapulcoite    907.87
# 25120           Miller Range 090042  55823    Valid           L6    242.60
# 4456                   Asuka 881471   4180    Valid           L5     13.70
# 20785             Lewis Cliff 88053  13807    Valid           H5      6.30
# 44015                 Yamato 981144  37766    Valid           H5      6.15
# 33695  Queen Alexandra Range 971014  20523    Valid          LL5      6.60
# 35840                        Rammya  22383    Valid           H5   2481.00
# 3652                    Asuka 87275   2632    Valid           H5    572.32
#
#         fall    year    reclat    reclong             GeoLocation
# 36158  Found  2004.0       NaN        NaN                     NaN
# ...

# %%
df_meteorites.shape
# Out:
# (45716, 10)

# %%
df_meteorites.size
# Out:
# 457160

# %%
df_meteorites.describe()
# Out:
#                  id      mass (g)          year        reclat       reclong
# count  45716.000000  4.558500e+04  45425.000000  38401.000000  38401.000000
# mean   26889.735104  1.327808e+04   1991.828817    -39.122580     61.074319
# std    16860.683030  5.749889e+05     25.052766     46.378511     80.647298
# min        1.000000  0.000000e+00    860.000000    -87.366670   -165.433330
# 25%    12688.750000  7.200000e+00   1987.000000    -76.714240      0.000000
# 50%    24261.500000  3.260000e+01   1998.000000    -71.500000     35.666670
# 75%    40656.750000  2.026000e+02   2003.000000      0.000000    157.166670
# max    57458.000000  6.000000e+07   2101.000000     81.166670    354.473330

# %%
pd.options.display.float_format = '{:1f}'.format

# %%
df_meteorites.describe()
# Out:
#                 id        mass (g)         year       reclat      reclong
# count 45716.000000    45585.000000 45425.000000 38401.000000 38401.000000
# mean  26889.735104    13278.078549  1991.828817   -39.122580    61.074319
# std   16860.683030   574988.876410    25.052766    46.378511    80.647298
# min       1.000000        0.000000   860.000000   -87.366670  -165.433330
# 25%   12688.750000        7.200000  1987.000000   -76.714240     0.000000
# 50%   24261.500000       32.600000  1998.000000   -71.500000    35.666670
# 75%   40656.750000      202.600000  2003.000000     0.000000   157.166670
# max   57458.000000 60000000.000000  2101.000000    81.166670   354.473330

# %%
df_meteorites.describe(include='all')
# Out:
#           name           id nametype recclass        mass (g)   fall  \
# count    45716 45716.000000    45716    45716    45585.000000  45716
# unique   45716          NaN        2      466             NaN      2
# top     Aachen          NaN    Valid       L6             NaN  Found
# freq         1          NaN    45641     8285             NaN  44609
# mean       NaN 26889.735104      NaN      NaN    13278.078549    NaN
# std        NaN 16860.683030      NaN      NaN   574988.876410    NaN
# min        NaN     1.000000      NaN      NaN        0.000000    NaN
# 25%        NaN 12688.750000      NaN      NaN        7.200000    NaN
# 50%        NaN 24261.500000      NaN      NaN       32.600000    NaN
# 75%        NaN 40656.750000      NaN      NaN      202.600000    NaN
# max        NaN 57458.000000      NaN      NaN 60000000.000000    NaN
#
#                year       reclat      reclong GeoLocation
# count  45425.000000 38401.000000 38401.000000       38401
# ...

# %%
df_meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.5+ MB

# %%
df_meteorites.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year           float64
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
df_meteorites.convert_dtypes().dtypes
# Out:
# name            string
# id               Int64
# nametype        string
# recclass        string
# mass (g)       Float64
# fall            string
# year             Int64
# reclat         Float64
# reclong        Float64
# GeoLocation     string
# dtype: object

# %%
df_meteorites.nunique()
# Out:
# name           45716
# id             45716
# nametype           2
# recclass         466
# mass (g)       12576
# fall               2
# year             265
# reclat         12738
# reclong        14640
# GeoLocation    17100
# dtype: int64

# %%
df_meteorites[['fall', 'nametype']]
# Out:
#         fall nametype
# 0       Fell    Valid
# 1       Fell    Valid
# 2       Fell    Valid
# 3       Fell    Valid
# 4       Fell    Valid
# ...      ...      ...
# 45711  Found    Valid
# 45712  Found    Valid
# 45713  Found    Valid
# 45714  Found    Valid
# 45715  Found    Valid
#
# [45716 rows x 2 columns]

# %%
df_meteorites[['fall', 'nametype']] = df_meteorites[['fall', 'nametype']].astype('category')

# %%
df_meteorites.dtypes
# Out:
# name             object
# id                int64
# nametype       category
# recclass         object
# mass (g)        float64
# fall           category
# year            float64
# reclat          float64
# reclong         float64
# GeoLocation      object
# dtype: object

# %%
df_meteorites['fall'].unique()
# Out:
# ['Fell', 'Found']
# Categories (2, object): ['Fell', 'Found']

# %%
df_meteorites['fall'].value_counts()
# Out:
# Found    44609
# Fell      1107
# Name: fall, dtype: int64

# %%
pd.get_dummies(df_meteorites['fall'])
# Out:
#        Fell  Found
# 0         1      0
# 1         1      0
# 2         1      0
# 3         1      0
# 4         1      0
# ...     ...    ...
# 45711     0      1
# 45712     0      1
# 45713     0      1
# 45714     0      1
# 45715     0      1
#
# [45716 rows x 2 columns]

# %%
df_meteorites['Ones'] = 1
df_meteorites
# Out:
#              name     id nametype              recclass      mass (g)   fall  \
# 0          Aachen      1    Valid                    L5     21.000000   Fell
# 1          Aarhus      2    Valid                    H6    720.000000   Fell
# 2            Abee      6    Valid                   EH4 107000.000000   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1914.000000   Fell
# 4         Achiras    370    Valid                    L6    780.000000   Fell
# ...           ...    ...      ...                   ...           ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite    172.000000  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped     46.000000  Found
# 45713        Zlin  30410    Valid                    H4      3.300000  Found
# 45714   Zubkovsky  31357    Valid                    L6   2167.000000  Found
# 45715  Zulu Queen  30414    Valid                  L3.7    200.000000  Found
#
# ...

# %%
df_meteorites[['fell', 'found']] = pd.get_dummies(df_meteorites['fall'])

# %%
df_meteorites
# Out:
#              name     id nametype              recclass      mass (g)   fall  \
# 0          Aachen      1    Valid                    L5     21.000000   Fell
# 1          Aarhus      2    Valid                    H6    720.000000   Fell
# 2            Abee      6    Valid                   EH4 107000.000000   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1914.000000   Fell
# 4         Achiras    370    Valid                    L6    780.000000   Fell
# ...           ...    ...      ...                   ...           ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite    172.000000  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped     46.000000  Found
# 45713        Zlin  30410    Valid                    H4      3.300000  Found
# 45714   Zubkovsky  31357    Valid                    L6   2167.000000  Found
# 45715  Zulu Queen  30414    Valid                  L3.7    200.000000  Found
#
# ...

# %%
df_meteorites['year']
# Out:
# 0       1880.000000
# 1       1951.000000
# 2       1952.000000
# 3       1976.000000
# 4       1902.000000
#             ...
# 45711   1990.000000
# 45712   1999.000000
# 45713   1939.000000
# 45714   2003.000000
# 45715   1976.000000
# Name: year, Length: 45716, dtype: float64

# %%
#Esto no lo pude hacer
df_meteorites['year'] = pd.to_datetime( df_meteorites['year'], errors='coerce', format = '%m/%d/%Y %H:%M:S %p')

# %%
df_meteorites.convert_dtypes().dtypes
# Out:
# name                   string
# id                      Int64
# nametype             category
# recclass               string
# mass (g)              Float64
# fall                 category
# year           datetime64[ns]
# reclat                Float64
# reclong               Float64
# GeoLocation            string
# Ones                    Int64
# fell                    UInt8
# found                   UInt8
# dtype: object

# %%
df_meteorites.rename(columns={'mass (g)':'mass'}, inplace=True)

# %%
df_meteorites
# Out:
#              name     id nametype              recclass          mass   fall  \
# 0          Aachen      1    Valid                    L5     21.000000   Fell
# 1          Aarhus      2    Valid                    H6    720.000000   Fell
# 2            Abee      6    Valid                   EH4 107000.000000   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1914.000000   Fell
# 4         Achiras    370    Valid                    L6    780.000000   Fell
# ...           ...    ...      ...                   ...           ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite    172.000000  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped     46.000000  Found
# 45713        Zlin  30410    Valid                    H4      3.300000  Found
# 45714   Zubkovsky  31357    Valid                    L6   2167.000000  Found
# 45715  Zulu Queen  30414    Valid                  L3.7    200.000000  Found
#
# ...

# %%
list(df_meteorites)
# Out:
# ['name',
#  'id',
#  'nametype',
#  'recclass',
#  'mass',
#  'fall',
#  'year',
#  'reclat',
#  'reclong',
#  'GeoLocation',
#  'Ones',
#  'fell',
#  'found']

# %%
df_meteorites.head(5)
# Out:
#        name   id nametype     recclass          mass  fall year     reclat  \
# 0    Aachen    1    Valid           L5     21.000000  Fell  NaT  50.775000
# 1    Aarhus    2    Valid           H6    720.000000  Fell  NaT  56.183330
# 2      Abee    6    Valid          EH4 107000.000000  Fell  NaT  54.216670
# 3  Acapulco   10    Valid  Acapulcoite   1914.000000  Fell  NaT  16.883330
# 4   Achiras  370    Valid           L6    780.000000  Fell  NaT -33.166670
#
#       reclong           GeoLocation  Ones  fell  found
# 0    6.083330     (50.775, 6.08333)     1     1      0
# 1   10.233330  (56.18333, 10.23333)     1     1      0
# 2 -113.000000    (54.21667, -113.0)     1     1      0
# 3  -99.900000     (16.88333, -99.9)     1     1      0
# 4  -64.950000   (-33.16667, -64.95)     1     1      0

# %%
df_meteorites.drop(['Ones'], axis=1, inplace=True)

# %%
df_meteorites.drop([0,2,4,6])
# Out:
#              name     id nametype              recclass         mass   fall  \
# 1          Aarhus      2    Valid                    H6   720.000000   Fell
# 3        Acapulco     10    Valid           Acapulcoite  1914.000000   Fell
# 5        Adhi Kot    379    Valid                   EH4  4239.000000   Fell
# 7            Agen    392    Valid                    H5 30000.000000   Fell
# 8          Aguada    398    Valid                    L6  1620.000000   Fell
# ...           ...    ...      ...                   ...          ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite   172.000000  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped    46.000000  Found
# 45713        Zlin  30410    Valid                    H4     3.300000  Found
# 45714   Zubkovsky  31357    Valid                    L6  2167.000000  Found
# 45715  Zulu Queen  30414    Valid                  L3.7   200.000000  Found
#
# ...

# %%
df_meteorites.drop(columns=['id', 'recclass'], index=[0, 2, 4, 6])
# Out:
#              name nametype         mass   fall year     reclat     reclong  \
# 1          Aarhus    Valid   720.000000   Fell  NaT  56.183330   10.233330
# 3        Acapulco    Valid  1914.000000   Fell  NaT  16.883330  -99.900000
# 5        Adhi Kot    Valid  4239.000000   Fell  NaT  32.100000   71.800000
# 7            Agen    Valid 30000.000000   Fell  NaT  44.216670    0.616670
# 8          Aguada    Valid  1620.000000   Fell  NaT -31.600000  -65.233330
# ...           ...      ...          ...    ...  ...        ...         ...
# 45711  Zillah 002    Valid   172.000000  Found  NaT  29.037000   17.018500
# 45712      Zinder    Valid    46.000000  Found  NaT  13.783330    8.966670
# 45713        Zlin    Valid     3.300000  Found  NaT  49.250000   17.666670
# 45714   Zubkovsky    Valid  2167.000000  Found  NaT  49.789170   41.504600
# 45715  Zulu Queen    Valid   200.000000  Found  NaT  33.983330 -115.683330
#
#                   GeoLocation  fell  found
# ...

# %%
df = df_meteorites.copy(deep = True)
df.drop(['id'], axis=1, inplace = True)

# %%
#df_meteorites
df
# Out:
#              name nametype              recclass          mass   fall year  \
# 0          Aachen    Valid                    L5     21.000000   Fell  NaT
# 1          Aarhus    Valid                    H6    720.000000   Fell  NaT
# 2            Abee    Valid                   EH4 107000.000000   Fell  NaT
# 3        Acapulco    Valid           Acapulcoite   1914.000000   Fell  NaT
# 4         Achiras    Valid                    L6    780.000000   Fell  NaT
# ...           ...      ...                   ...           ...    ...  ...
# 45711  Zillah 002    Valid               Eucrite    172.000000  Found  NaT
# 45712      Zinder    Valid  Pallasite, ungrouped     46.000000  Found  NaT
# 45713        Zlin    Valid                    H4      3.300000  Found  NaT
# 45714   Zubkovsky    Valid                    L6   2167.000000  Found  NaT
# 45715  Zulu Queen    Valid                  L3.7    200.000000  Found  NaT
#
#           reclat     reclong             GeoLocation  fell  found
# ...
